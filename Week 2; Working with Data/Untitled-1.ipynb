# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([15, 25, 10, 5])
names = ["Yusuf", "Barnabas", "Chadek", "Dante"]
myexplode = [0, 0.2, 0, 0]


plt.pie(y, labels = names, startangle = 90, explode = myexplode, shadow = True)
plt.legend(title = "Applicants:")
plt.show()
