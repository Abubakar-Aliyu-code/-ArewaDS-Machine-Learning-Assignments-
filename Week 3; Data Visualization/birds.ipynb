# %%
import pandas as pd
import matplotlib.pyplot as plt
birds = pd.read_csv("C:\\Users\HP\Desktop\\-ArewaDS-Machine-Learning-Assignments-\\Data\\birds.csv")
birds.head()

filteredBirds = birds[(birds['MaxBodyMass'] > 1) & (birds['MaxBodyMass'] < 60)]      


import seaborn as sns
sns.kdeplot(data=filteredBirds, x="MinLength", y="MaxLength", hue="ConservationStatus")
# Out:
# c:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:1106: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='MinLength', ylabel='MaxLength'>
