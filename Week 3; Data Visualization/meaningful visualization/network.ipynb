# %%
import pandas as pd
import numpy as np
import geopandas
import random

df = pd.read_json('letters.json')

names = [
      "Muhammad Ibrahim",
      "Maryam Ibrahim",
      "Ibrahim Isah",
      "Aisha Sani",
      "Fatima, Ibrahim",
      "Amina Ibrahim",
      "Zainab Ibrahim",
      "Rukayya Ibrahim",
      "Sani Abdullahi",
      "Umar Siraj",
      "Yusif Kabir",
      "Usman",
      "Mahmud Musa",
      "Jamila Ibrahim",
      "Nura Abdullahi",
    ]




from_lst = []

while len(df['from']) != len(from_lst):
    name = random.choice(names)
    from_lst.append(name)
    names.remove(name)
    if len(names) == 0:
        names = ["Muhammad Ibrahim ","Maryam Ibrahim","Ibrahim Isah","Aisha Sani","Fatima, Ibrahim","Amina Ibrahim","Zainab Ibrahim","Rukayya Ibrahim","Sani Abdullahi","Umar Siraj","Yusif Kabir","Usman","Mahmud Musa","Jamila Ibrahim","Nura Abdullahi",]

df['from'] = from_lst




to_lst = []

while len(df['from']) != len(to_lst):
    name = random.choice(names)
    to_lst.append(name)
    names.remove(name)
    if len(names) == 0:
        names = ["Muhammad Ibrahim ","Maryam Ibrahim","Ibrahim Isah","Aisha Sani","Fatima, Ibrahim","Amina Ibrahim","Zainab Ibrahim","Rukayya Ibrahim","Sani Abdullahi","Umar Siraj","Yusif Kabir","Usman","Mahmud Musa","Jamila Ibrahim","Nura Abdullahi",]

df['to'] = to_lst



locations = ['Kano','Abuja','Katsina','Sokoto','Kebbi','Saudia','Lagos','Adamawa','Yobe','Borno','Taraba','USA','China'];



loc_lst = [ ]

while len(df['location']) != len(loc_lst):
    location = random.choice(locations)
    loc_lst.append(location)
    locations.remove(location)
    if len(locations) == 0:
        locations = ['Kano','Abuja','Katsina','Sokoto','Kebbi','Saudia','Lagos','Adamawa','Yobe','Borno','Taraba','USA','China']

df['location'] = loc_lst



df.to_json(r'C:\Users\HP\Desktop\-ArewaDS-Machine-Learning-Assignments-\Data\letter.json',indent=True,orient='records')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import geopandas
#       4 import random
#       6 df = pd.read_json('letters.json')
#
# ModuleNotFoundError: No module named 'geopandas'
